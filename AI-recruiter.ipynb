# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (3.6.6)
# Requirement already satisfied: joblib in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from nltk) (8.0.3)
# Requirement already satisfied: tqdm in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from nltk) (4.62.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from nltk) (2021.11.10)
# Requirement already satisfied: colorama in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from click->nltk) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spacy==2.3.5
# Out:
# Collecting spacy==2.3.5
#   Downloading spacy-2.3.5-cp38-cp38-win_amd64.whl (9.7 MB)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.5-cp38-cp38-win_amd64.whl (910 kB)
# Collecting srsly<1.1.0,>=1.0.2Note: you may need to restart the kernel to use updated packages.
#
#   Downloading srsly-1.0.5-cp38-cp38-win_amd64.whl (178 kB)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy==2.3.5) (1.0.6)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: setuptools in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy==2.3.5) (58.0.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy==2.3.5) (1.21.2)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\dimpu\\anaconda3\\envs\\testing123\\Lib\\site-packages\\~rsly\\msgpack\\_packer.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy==2.3.5) (0.7.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy==2.3.5) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy==2.3.5) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy==2.3.5) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy==2.3.5) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy==2.3.5) (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (2.0.4)
# Requirement already satisfied: colorama in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy==2.3.5) (0.4.4)
# Installing collected packages: srsly, plac, catalogue, thinc, spacy
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.2
#     Uninstalling srsly-2.4.2:
#       Successfully uninstalled srsly-2.4.2

# %%
pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gzNote: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\dimpu\\anaconda3\\envs\\testing123\\Lib\\site-packages\\~hinc\\backends\\linalg.cp38-win_amd64.pyd'
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0 MB)
# Collecting spacy<2.4.0,>=2.3.0
#   Downloading spacy-2.3.7-cp38-cp38-win_amd64.whl (9.7 MB)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.21.2)
# Collecting plac<1.2.0,>=0.9.6
#   Using cached plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (0.7.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2.26.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (3.0.6)
# Requirement already satisfied: setuptools in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (58.0.4)
# Collecting thinc<7.5.0,>=7.4.1
#   Using cached thinc-7.4.5-cp38-cp38-win_amd64.whl (910 kB)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (4.62.3)
# Collecting catalogue<1.1.0,>=0.0.7
#   Using cached catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2021.10.8)
# Requirement already satisfied: colorama in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (0.4.4)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py): started
#   Building wheel for en-core-web-sm (setup.py): finished with status 'done'
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.3.1-py3-none-any.whl size=12047105 sha256=464100c6a28809c6c938ce458a4d8593d4055d0a328f14a8bf2ff8646faa8241
#   Stored in directory: c:\users\dimpu\appdata\local\pip\cache\wheels\ee\4d\f7\563214122be1540b5f9197b52cb3ddb9c4a8070808b22d5a84
# Successfully built en-core-web-sm
# Installing collected packages: plac, catalogue, thinc, spacy, en-core-web-sm
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.6
#     Uninstalling catalogue-2.0.6:
#       Successfully uninstalled catalogue-2.0.6
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.13
#     Uninstalling thinc-8.0.13:
#       Successfully uninstalled thinc-8.0.13
# Consider using the `--user` option or check the permissions.

# %%
pip install pyresparser
# Out:
# Requirement already satisfied: pyresparser in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (1.0.6)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: spacy>=2.1.4 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (3.2.1)
# Requirement already satisfied: pyrsistent>=0.15.2 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (0.17.3)
# Requirement already satisfied: pytz>=2019.1 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (2021.3)
# Requirement already satisfied: nltk>=3.4.3 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (3.6.6)
# Requirement already satisfied: pdfminer.six>=20181108 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (20211012)
# Requirement already satisfied: requests>=2.22.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (2.26.0)
# Requirement already satisfied: blis>=0.2.4 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (0.7.5)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (3.2.0)
# Requirement already satisfied: sortedcontainers>=2.1.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (2.4.0)
# Requirement already satisfied: certifi>=2019.6.16 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (2021.10.8)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (1.3.5)
# Requirement already satisfied: idna>=2.8 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (3.2)
# Requirement already satisfied: chardet>=3.0.4 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (4.0.0)
# Requirement already satisfied: docx2txt>=0.7 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (0.8)
# Requirement already satisfied: six>=1.12.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (1.16.0)
# Requirement already satisfied: pycryptodome>=3.8.2 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (3.12.0)
# Requirement already satisfied: urllib3>=1.25.3 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (1.26.7)
# Requirement already satisfied: preshed>=2.0.1 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (3.0.6)
# Requirement already satisfied: wasabi>=0.2.2 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (0.9.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (21.2.0)
# Requirement already satisfied: thinc>=7.0.4 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (8.0.13)
# Requirement already satisfied: tqdm>=4.32.2 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (4.62.3)
# Requirement already satisfied: numpy>=1.16.4 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (1.21.2)
# Requirement already satisfied: srsly>=0.0.7 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (2.4.2)
# Requirement already satisfied: cymem>=2.0.2 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pyresparser) (2.8.2)
# Requirement already satisfied: setuptools in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from jsonschema>=3.0.1->pyresparser) (58.0.4)
# Requirement already satisfied: click in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from nltk>=3.4.3->pyresparser) (8.0.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from nltk>=3.4.3->pyresparser) (2021.11.10)
# Requirement already satisfied: joblib in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from nltk>=3.4.3->pyresparser) (1.1.0)
# Requirement already satisfied: cryptography in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pdfminer.six>=20181108->pyresparser) (3.4.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from preshed>=2.0.1->pyresparser) (1.0.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from requests>=2.22.0->pyresparser) (2.0.4)
# Requirement already satisfied: jinja2 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy>=2.1.4->pyresparser) (3.0.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy>=2.1.4->pyresparser) (3.3.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy>=2.1.4->pyresparser) (0.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy>=2.1.4->pyresparser) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy>=2.1.4->pyresparser) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy>=2.1.4->pyresparser) (21.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy>=2.1.4->pyresparser) (1.0.1)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy>=2.1.4->pyresparser) (0.6.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from spacy>=2.1.4->pyresparser) (2.0.6)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from packaging>=20.0->spacy>=2.1.4->pyresparser) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pathy>=0.3.5->spacy>=2.1.4->pyresparser) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy>=2.1.4->pyresparser) (3.10.0.2)
# Requirement already satisfied: colorama in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from tqdm>=4.32.2->pyresparser) (0.4.4)
# Requirement already satisfied: cffi>=1.12 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from cryptography->pdfminer.six>=20181108->pyresparser) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from cffi>=1.12->cryptography->pdfminer.six>=20181108->pyresparser) (2.20)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dimpu\anaconda3\envs\testing123\lib\site-packages (from jinja2->spacy>=2.1.4->pyresparser) (2.0.1)

# %%
# Library to have connection to your gmail
import smtplib
# library to extract the entities form your resume
from pyresparser import ResumeParser
import nltk
stopwords = nltk.corpus.stopwords.words('english')


# creates SMTP session 
s = smtplib.SMTP('smtp.gmail.com', 587) 
# start TLS for security
s.starttls() 

# Authentication 
s.login("varangantikavya29@gmail.com","Kavya12345") 

# give a subject   
SUBJECT = "Interview Call"

# skills requirement for Ai developer
python_skills = ["ml","ai","matplotlib","seabon",
                 "python","reression","algorithms", 
                 "Pandas","data analysis","keras",
                 "tensorflow","artificial intelligence",
                 "data visualization","opencv"]
# skills requirement for Java developer
java_skills  = []

# extract the skills from resume
data = ResumeParser('PradeepthiResume.pdf').get_extracted_data()

print(data)
# grab the name
name = data['name']
# grab the Email
email = data['email']
# grab the Skills
skills = data["skills"]
# lowercase the skills
actual_skills = [i.lower() for i in skills ]

  
# using list comprehension 
# checking if string contains list element 
Skills_matched = [ele for ele in actual_skills 
                if(ele in python_skills)] 



# check the number of skills matched
if(len(Skills_matched) >= 4 ):
    
    print("he is eligible")
    # create a text that is to sent in an email
    TEXT = "Hello " + name + ",\n\nThanks for applying to the job post-AI/ML Developer. Your skill matches our requirements. Kindly, let us know your available time for initial round of interview.\n\nThanks and Regards,\n\nTalent acquisition team | SmartBridge"
    # send mail
    message  = 'Subject: {}\n\n{}'.format(SUBJECT, TEXT)
    #send the mail
    s.sendmail("kavyavaranganti56@gmail.com", email, message) 
    #quit the session
    s.quit()    
else:
    print("sorry we cant process your candidate")

    TEXT = "Hello " + name + ",\n\nThanks for applying to the job post-AI/ML Developer. Your candidate is rejected.\n\nThanks and Regards,\n\nTalent acquisition team | SmartBridge"
    message  = 'Subject: {}\n\n{}'.format(SUBJECT, TEXT)
    s.sendmail("kavyavaranganti56@gmail.com", email, message) 
    s.quit()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10984/136617502.py in <module>
#      28
#      29 # extract the skills from resume
# ---> 30 data = ResumeParser('PradeepthiResume.pdf').get_extracted_data()
#      31
#      32 print(data)
#
# ~\anaconda3\envs\testing123\lib\site-packages\pyresparser\resume_parser.py in __init__(self, resume, skills_file, custom_regex)
#      18         custom_regex=None
#      19     ):
# ---> 20         nlp = spacy.load('en_core_web_sm')
#      21         custom_nlp = spacy.load(os.path.dirname(os.path.abspath(__file__)))
#      22         self.__skills_file = skills_file
#
# ~\anaconda3\envs\testing123\lib\site-packages\spacy\__init__.py in load(name, vocab, disable, exclude, config)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#
# ~\anaconda3\envs\testing123\lib\site-packages\spacy\util.py in load_model(name, vocab, disable, exclude, config)
#     425     if name in OLD_MODEL_SHORTCUTS:
#     426         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 427     raise IOError(Errors.E050.format(name=name))
#     428
#     429
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.
